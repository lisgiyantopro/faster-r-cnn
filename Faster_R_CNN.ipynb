# %% [markdown]
# <a href="https://colab.research.google.com/github/lisgiyantopro/faster-r-cnn/blob/main/Faster_R_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lisgiyantopro/faster-r-cnn.git
# Out:
# fatal: destination path 'faster-r-cnn' already exists and is not an empty directory.
